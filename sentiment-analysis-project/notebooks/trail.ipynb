# %%
import nltk
from nltk.tokenize import word_tokenize

text = "I can't believe the U.S. movie cost $20.50!"
print(word_tokenize(text))

# Output: ['I', 'ca', "n't", 'believe', 'the', 'U.S.', 'movie', 'cost', '$', '20.50', '!']
# Out:
# ['I', 'ca', "n't", 'believe', 'the', 'U.S.', 'movie', 'cost', '$', '20.50', '!']
